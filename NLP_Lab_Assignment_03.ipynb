# %% [markdown]
# <a href="https://colab.research.google.com/github/BandiSreesaicharan/NLP/blob/main/NLP_Lab_Assignment_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TASK #**02**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""
tokens = nltk.word_tokenize(SRUniversity)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('The', 'DT'), ('SR', 'NNP'), ('University', 'NNP'), ('campus', 'NN'), ('is', 'VBZ'), ('located', 'VBN'), ('in', 'IN'), ('Ananthasagar', 'NNP'), ('village', 'NN'), ('of', 'IN'), ('Hasanparthy', 'NNP'), ('Mandal', 'NNP'), ('in', 'IN'), ('Warangal', 'NNP'), (',', ','), ('Telangana', 'NNP'), (',', ','), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('in', 'IN'), ('150', 'CD'), ('acres', 'NNS'), (',', ','), ('with', 'IN'), ('both', 'DT'), ('separate', 'JJ'), ('hostel', 'NN'), ('facilities', 'NNS'), ('for', 'IN'), ('boys', 'NNS'), ('and', 'CC'), ('girls', 'NNS'), ('.', '.'), ('There', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('huge', 'JJ'), ('central', 'JJ'), ('library', 'NN'), ('along', 'IN'), ('with', 'IN'), ('Indias', 'NNP'), ('largest', 'JJS'), ('Technology', 'NN'), ('Business', 'NNP'), ('Incubator', 'NNP'), ('(', '('), ('TBI', 'NNP'), (')', ')'), ('in', 'IN'), ('tier', '$'), ('2', 'CD'), ('cities', 'NNS'), ('.', '.')]
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_)
# Out:
# The DET
# SR PROPN
# University PROPN
# campus NOUN
# is AUX
# located VERB
# in ADP
# Ananthasagar PROPN
# village NOUN
# of ADP
# Hasanparthy PROPN
# Mandal PROPN
# in ADP
# Warangal PROPN
# , PUNCT
# Telangana PROPN
# , PUNCT
# India PROPN
# . PUNCT
#
#  SPACE
# It PRON
# is AUX
# in ADP
# 150 NUM
# acres NOUN
# , PUNCT
# with ADP
# both DET
# separate ADJ
# hostel NOUN
# facilities NOUN
# for ADP
# boys NOUN
# and CCONJ
# girls NOUN
# . PUNCT
#
#  SPACE
# There PRON
# is VERB
# a DET
# huge ADJ
# central ADJ
# library NOUN
# along ADP
# with ADP
# Indias PROPN
# largest ADJ
# Technology PROPN
# Business PROPN
# Incubator PROPN
# ( PUNCT
# TBI PROPN
# ) PUNCT
# in ADP
# tier NOUN
# 2 NUM
# cities NOUN
# . PUNCT

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(SRUniversity)
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# The DET DT
# SR PROPN NNP
# University PROPN NNP
# campus NOUN NN
# is AUX VBZ
# located VERB VBN
# in ADP IN
# Ananthasagar PROPN NNP
# village NOUN NN
# of ADP IN
# Hasanparthy PROPN NNP
# Mandal PROPN NNP
# in ADP IN
# Warangal PROPN NNP
# , PUNCT ,
# Telangana PROPN NNP
# , PUNCT ,
# India PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# It PRON PRP
# is AUX VBZ
# in ADP IN
# 150 NUM CD
# acres NOUN NNS
# , PUNCT ,
# with ADP IN
# both DET DT
# separate ADJ JJ
# hostel NOUN NN
# facilities NOUN NNS
# for ADP IN
# boys NOUN NNS
# and CCONJ CC
# girls NOUN NNS
# . PUNCT .
#
#  SPACE _SP
# There PRON EX
# is VERB VBZ
# a DET DT
# huge ADJ JJ
# central ADJ JJ
# library NOUN NN
# along ADP IN
# with ADP IN
# Indias PROPN NNP
# largest ADJ JJS
# Technology PROPN NNP
# Business PROPN NNP
# Incubator PROPN NNP
# ( PUNCT -LRB-
# TBI PROPN NNP
# ) PUNCT -RRB-
# in ADP IN
# tier NOUN NN
# 2 NUM CD
# cities NOUN NNS
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""
doc = nlp(SRUniversity)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'SR': 1, 'University': 1, 'campus': 1, 'Ananthasagar': 1, 'village': 1, 'Hasanparthy': 1, 'Mandal': 1, 'Warangal': 1, 'Telangana': 1, 'India': 1, 'acres': 1, 'hostel': 1, 'facilities': 1, 'boys': 1, 'girls': 1, 'library': 1, 'Indias': 1, 'Technology': 1, 'Business': 1, 'Incubator': 1, 'TBI': 1, 'tier': 1, 'cities': 1})
# Verb Frequency: Counter({'located': 1, 'is': 1})

# %% [markdown]
# # TASK #**1**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
sentence = "Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Students are learning Natural Language Processing")
for token in doc:
  print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learning VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Loving the new AI features  #AI #MachineLearning"
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'AI': 2, 'MachineLearning': 1})
# Verb Frequency: Counter({'Loving': 1, 'features': 1})

# %% [markdown]
# # Task #**3**

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
text = "Technology shapes modern life in subtle, powerful ways. Every click, sensor, and algorithm quietly collects signals, transforms them into data, and drives decisions at remarkable speed. For students, learning technology is no longer optional; it is a language for problem solving. Curiosity fuels progress, while discipline turns ideas into reliable systems. Mistakes reveal hidden assumptions and invite better designs. Ethical thinking must guide innovation, ensuring tools empower people rather than exploit them. When skill meets responsibility, technology becomes a force for resilience, creativity, and shared growth across communities worldwide. Built carefully, thoughtfully, collaboratively, sustainably, openly, globally, adaptively, inclusively, securely, continuously."
tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Technology', 'NNP'), ('shapes', 'VBZ'), ('modern', 'JJ'), ('life', 'NN'), ('in', 'IN'), ('subtle', 'JJ'), (',', ','), ('powerful', 'JJ'), ('ways', 'NNS'), ('.', '.'), ('Every', 'NNP'), ('click', 'NN'), (',', ','), ('sensor', 'NN'), (',', ','), ('and', 'CC'), ('algorithm', 'RB'), ('quietly', 'RB'), ('collects', 'VBZ'), ('signals', 'NNS'), (',', ','), ('transforms', 'VBZ'), ('them', 'PRP'), ('into', 'IN'), ('data', 'NNS'), (',', ','), ('and', 'CC'), ('drives', 'VBZ'), ('decisions', 'NNS'), ('at', 'IN'), ('remarkable', 'JJ'), ('speed', 'NN'), ('.', '.'), ('For', 'IN'), ('students', 'NNS'), (',', ','), ('learning', 'VBG'), ('technology', 'NN'), ('is', 'VBZ'), ('no', 'DT'), ('longer', 'RBR'), ('optional', 'JJ'), (';', ':'), ('it', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('language', 'NN'), ('for', 'IN'), ('problem', 'NN'), ('solving', 'NN'), ('.', '.'), ('Curiosity', 'NNP'), ('fuels', 'JJ'), ('progress', 'NN'), (',', ','), ('while', 'IN'), ('discipline', 'NN'), ('turns', 'VBZ'), ('ideas', 
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "Technology shapes modern life in subtle, powerful ways. Every click, sensor, and algorithm quietly collects signals, transforms them into data, and drives decisions at remarkable speed. For students, learning technology is no longer optional; it is a language for problem solving. Curiosity fuels progress, while discipline turns ideas into reliable systems. Mistakes reveal hidden assumptions and invite better designs. Ethical thinking must guide innovation, ensuring tools empower people rather than exploit them. When skill meets responsibility, technology becomes a force for resilience, creativity, and shared growth across communities worldwide. Built carefully, thoughtfully, collaboratively, sustainably, openly, globally, adaptively, inclusively, securely, continuously."
doc = nlp(text)
for token in doc:
  print(token.text, token.pos_)
# Out:
# Technology NOUN
# shapes VERB
# modern ADJ
# life NOUN
# in ADP
# subtle ADJ
# , PUNCT
# powerful ADJ
# ways NOUN
# . PUNCT
# Every DET
# click NOUN
# , PUNCT
# sensor NOUN
# , PUNCT
# and CCONJ
# algorithm PROPN
# quietly ADV
# collects VERB
# signals NOUN
# , PUNCT
# transforms VERB
# them PRON
# into ADP
# data NOUN
# , PUNCT
# and CCONJ
# drives VERB
# decisions NOUN
# at ADP
# remarkable ADJ
# speed NOUN
# . PUNCT
# For ADP
# students NOUN
# , PUNCT
# learning VERB
# technology NOUN
# is AUX
# no PRON
# longer ADV
# optional ADJ
# ; PUNCT
# it PRON
# is AUX
# a DET
# language NOUN
# for ADP
# problem NOUN
# solving VERB
# . PUNCT
# Curiosity NOUN
# fuels NOUN
# progress VERB
# , PUNCT
# while SCONJ
# discipline NOUN
# turns VERB
# ideas NOUN
# into ADP
# reliable ADJ
# systems NOUN
# . PUNCT
# Mistakes NOUN
# reveal VERB
# hidden ADJ
# assumptions NOUN
# and CCONJ
# invite VERB
# better ADJ
# designs NOUN
# . PUNCT
# Ethical ADJ
# thinking NOUN
# must AUX
# guide VERB
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "Technology shapes modern life in subtle, powerful ways. Every click, sensor, and algorithm quietly collects signals, transforms them into data, and drives decisions at remarkable speed. For students, learning technology is no longer optional; it is a language for problem solving. Curiosity fuels progress, while discipline turns ideas into reliable systems. Mistakes reveal hidden assumptions and invite better designs. Ethical thinking must guide innovation, ensuring tools empower people rather than exploit them. When skill meets responsibility, technology becomes a force for resilience, creativity, and shared growth across communities worldwide. Built carefully, thoughtfully, collaboratively, sustainably, openly, globally, adaptively, inclusively, securely, continuously."
doc = nlp(text)
for token in doc:
  print(token.text, token.pos_, token.tag_)
# Out:
# Technology NOUN NN
# shapes VERB VBZ
# modern ADJ JJ
# life NOUN NN
# in ADP IN
# subtle ADJ JJ
# , PUNCT ,
# powerful ADJ JJ
# ways NOUN NNS
# . PUNCT .
# Every DET DT
# click NOUN NN
# , PUNCT ,
# sensor NOUN NN
# , PUNCT ,
# and CCONJ CC
# algorithm PROPN NNP
# quietly ADV RB
# collects VERB VBZ
# signals NOUN NNS
# , PUNCT ,
# transforms VERB VBZ
# them PRON PRP
# into ADP IN
# data NOUN NNS
# , PUNCT ,
# and CCONJ CC
# drives VERB VBZ
# decisions NOUN NNS
# at ADP IN
# remarkable ADJ JJ
# speed NOUN NN
# . PUNCT .
# For ADP IN
# students NOUN NNS
# , PUNCT ,
# learning VERB VBG
# technology NOUN NN
# is AUX VBZ
# no PRON DT
# longer ADV RBR
# optional ADJ JJ
# ; PUNCT :
# it PRON PRP
# is AUX VBZ
# a DET DT
# language NOUN NN
# for ADP IN
# problem NOUN NN
# solving VERB VBG
# . PUNCT .
# Curiosity NOUN NN
# fuels NOUN NNS
# progress VERB VBP
# , PUNCT ,
# while SCONJ IN
# discipline NOUN NN
# turns VERB VBZ
# ideas NOUN NNS
# into ADP IN
# reliable ADJ JJ
# systems NOUN NNS
# ...

# %%
import spacy
from collections import Counter
nlp = spacy.load("en_core_web_sm")
text = "Technology shapes modern life in subtle, powerful ways. Every click, sensor, and algorithm quietly collects signals, transforms them into data, and drives decisions at remarkable speed. For students, learning technology is no longer optional; it is a language for problem solving. Curiosity fuels progress, while discipline turns ideas into reliable systems. Mistakes reveal hidden assumptions and invite better designs. Ethical thinking must guide innovation, ensuring tools empower people rather than exploit them. When skill meets responsibility, technology becomes a force for resilience, creativity, and shared growth across communities worldwide. Built carefully, thoughtfully, collaboratively, sustainably, openly, globally, adaptively, inclusively, securely, continuously."
doc = nlp(text)
nouns = []
verbs = []
for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)
noun_freq = Counter(nouns)
verb_freq = Counter(verbs)
print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'technology': 2, 'Technology': 1, 'life': 1, 'ways': 1, 'click': 1, 'sensor': 1, 'algorithm': 1, 'signals': 1, 'data': 1, 'decisions': 1, 'speed': 1, 'students': 1, 'language': 1, 'problem': 1, 'Curiosity': 1, 'fuels': 1, 'discipline': 1, 'ideas': 1, 'systems': 1, 'Mistakes': 1, 'assumptions': 1, 'designs': 1, 'thinking': 1, 'innovation': 1, 'tools': 1, 'people': 1, 'skill': 1, 'responsibility': 1, 'force': 1, 'resilience': 1, 'creativity': 1, 'growth': 1, 'communities': 1})
# Verb Frequency: Counter({'shapes': 1, 'collects': 1, 'transforms': 1, 'drives': 1, 'learning': 1, 'solving': 1, 'progress': 1, 'turns': 1, 'reveal': 1, 'invite': 1, 'guide': 1, 'ensuring': 1, 'empower': 1, 'exploit': 1, 'meets': 1, 'becomes': 1, 'shared': 1, 'Built': 1})
